# %%
#Twitter Analysis 

import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns# To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('###source of data###')  # load data set
data.head()
# Out:
#               Tweet id                                    Tweet permalink  \
# 0  1355586351161372675  https://twitter.com/collinsryan1993/status/135...
# 1  1355564457821429768  https://twitter.com/collinsryan1993/status/135...
# 2  1355334823888482305  https://twitter.com/collinsryan1993/status/135...
# 3  1355334430060142594  https://twitter.com/collinsryan1993/status/135...
# 4  1355303461282320384  https://twitter.com/collinsryan1993/status/135...
#
#                                           Tweet text                    time  \
# 0  I gave my LinkedIn header image another shot. ...  2021-01-30 18:39 +0000
# 1  "Robinhood’s distress follows a familiar narra...  2021-01-30 17:12 +0000
# 2  @MGLemieux @AcademicChatter Not at all. My pro...  2021-01-30 01:59 +0000
# 3  https://t.co/DaeI4vWdf5\n#altac #postac #jobse...  2021-01-30 01:58 +0000
# 4  Hoping this will lessen my stress. https://t.c...  2021-01-29 23:55 +0000
#
# ...

# %%
#likes 
X = data.iloc[:,7 ].values.reshape(-1, 1)

#imprssions
Y = data.iloc[:,4 ].values.reshape(-1, 1)

# %%
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(Likes, impressions)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
#create visualizatin in seaborn 
ax = sns.regplot(x=X, y=Y, data=data);
ax.set(xlabel=" Likes ", ylabel = " Impressions")
ax.set_title("My Personal Twitter Data from January")
# Out:
# Text(0.5, 1.0, 'My Personal Twitter Data from January')
